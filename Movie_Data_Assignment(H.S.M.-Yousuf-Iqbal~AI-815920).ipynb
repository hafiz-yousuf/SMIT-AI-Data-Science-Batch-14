# %% [markdown]
# # **Movie Dataset Python Assignment**

# %% [markdown]
# ### **Question 1**
# Dataset (`movie.csv`) ko pandas mein load karein aur uske pehle 5 rows display karein.

# %%
import pandas as pd
data=pd.read_csv("movie.csv")
data.head(5)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# 2  Christian Bale      2303232  534858444.0
# 3       Al Pacino      1129952   57300000.0
# 4     Henry Fonda       689845    4360000.0

# %% [markdown]
# ### **Question 2**
# Dataset ka total shape (rows aur columns count) check karke print karein.

# %%
data.shape
# Out:
# (1000, 11)

# %% [markdown]
# ### **Question 3**
# Check karein ki kis kis column mein missing values (null values) hain aur unka exact count kya hai.

# %%
data.isnull().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# Director           0
# Star1              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# ### **Question 4**
# Which movies were released after the year 2000? (Year 2000 ke baad release hone wali movies filter karein).

# %%
data.Released_Year[966]=2000
data.Released_Year=data.Released_Year.astype(int)
# Out:
# C:\Users\UT DELL\AppData\Local\Temp\ipykernel_10292\3428910995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Released_Year[966]=2000

# %%
data[data.Released_Year >= 2000]
# Out:
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight           2008
# 5        The Lord of the Rings: The Return of the King           2003
# 8                                            Inception           2010
# 10   The Lord of the Rings: The Fellowship of the Ring           2001
# 13               The Lord of the Rings: The Two Towers           2002
# ..                                                 ...            ...
# 949                                               Blow           2001
# 950                                 Enemy at the Gates           2001
# 951                                    Minority Report           2002
# 953                                    American Psycho           2000
# 966                                          Apollo 13           2000
#
#     Certificate  Runtime                      Genre  IMDB_Rating  Meta_score  \
# 2            UA  152 min       Action, Crime, Drama          9.0        84.0
# 5             U  201 min   Action, Adventure, Drama          8.9        94.0
# 8            UA  148 min  Action, Adventure, Sci-Fi          8.8        74.0
# 10            U  178 min   Action, Adventure, Drama          8.8        92.0
# 13           UA  179 min   Action, Adventure, Drama          8.7        87.0
# ..          ...      ...                        ...          ...         ...
# 949           R  124 min    Biography, Crime, Drama          7.6        52.0
# 950           A  131 min        Drama, History, War          7.6        53.0
# 951           A  145 min     Action, Crime, Mystery          7.6        80.0
# 953           A  101 min       Comedy, Crime, Drama          7.6        64.0
# 966           U  140 min  Adventure, Drama, History          7.6        77.0
#
#                 Director              Star1  No_of_Votes        Gross
# 2      Christopher Nolan     Christian Bale      2303232  534858444.0
# 5          Peter Jackson        Elijah Wood      1642758  377845905.0
# 8      Christopher Nolan  Leonardo DiCaprio      2067042  292576195.0
# 10         Peter Jackson        Elijah Wood      1661481  315544750.0
# 13         Peter Jackson        Elijah Wood      1485555  342551365.0
# ..                   ...                ...          ...          ...
# 949            Ted Demme        Johnny Depp       240714   52990775.0
# 950  Jean-Jacques Annaud           Jude Law       243729   51401758.0
# 951     Steven Spielberg         Tom Cruise       508417  132072926.0
# 953          Mary Harron     Christian Bale       490062   15070285.0
# 966           Ron Howard          Tom Hanks       269197  173837933.0
#
# [486 rows x 11 columns]

# %% [markdown]
# ### **Question 5**
# Which movies have an IMDB rating greater than 9? (9 se zyada IMDB rating wali movies display karein).

# %%
data[data.IMDB_Rating>9]
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption           1994           A  142 min         Drama
# 1             The Godfather           1972           A  175 min  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %% [markdown]
# ### **Question 6**
# How many movies are there for each genre? (Har genre ki total kitni movies hain, count nikalye).

# %%
data.Genre.value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %% [markdown]
# ### **Question 7**
# Which movies were directed by Christopher Nolan? (Christopher Nolan ki directed saari movies nikalye).

# %%
data[data.Director=="Christopher Nolan"]
# Out:
#               Series_Title  Released_Year Certificate  Runtime  \
# 2          The Dark Knight           2008          UA  152 min
# 8                Inception           2010          UA  148 min
# 21            Interstellar           2014          UA  169 min
# 36            The Prestige           2006           U  130 min
# 63   The Dark Knight Rises           2012          UA  164 min
# 69                 Memento           2000          UA  113 min
# 155          Batman Begins           2005          UA  140 min
# 573                Dunkirk           2017          UA  106 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 36      Drama, Mystery, Sci-Fi          8.5        66.0  Christopher Nolan
# 63           Action, Adventure          8.4        78.0  Christopher Nolan
# 69           Mystery, Thriller          8.4        80.0  Christopher Nolan
# 155          Action, Adventure          8.2        70.0  Christopher Nolan
# 573     Action, Drama, History          7.8        94.0  Christopher Nolan
#
#                    Star1  No_of_Votes        Gross
# 2         Christian Bale      2303232  534858444.0
# 8      Leonardo DiCaprio      2067042  292576195.0
# 21   Matthew McConaughey      1512360  188020017.0
# 36        Christian Bale      1190259   53089891.0
# 63        Christian Bale      1516346  448139099.0
# 69            Guy Pearce      1125712   25544867.0
# 155       Christian Bale      1308302  206852432.0
# 573      Fionn Whitehead       555092  188373161.0

# %% [markdown]
# ### **Question 8**
# Which movies have 'Drama' mentioned in their genre? ('Drama' genre wali movies ko filter karein).

# %%
data[data.Genre.str.contains("Drama")]
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 993                    Blowup           1966           A  111 min
# 995    Breakfast at Tiffany's           1961           A  115 min
# 996                     Giant           1956           G  201 min
# 997     From Here to Eternity           1953      Passed  118 min
# 998                  Lifeboat           1944         NaN   97 min
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# 2        Action, Crime, Drama          9.0        84.0
# 3                Crime, Drama          9.0        90.0
# 4                Crime, Drama          9.0        96.0
# ..                        ...          ...         ...
# 993  Drama, Mystery, Thriller          7.6        82.0
# 995    Comedy, Drama, Romance          7.6        76.0
# 996            Drama, Western          7.6        84.0
# 997       Drama, Romance, War          7.6        85.0
# 998                Drama, War          7.6        78.0
#
#                    Director              Star1  No_of_Votes        Gross
# 0            Frank Darabont        Tim Robbins      2343110   28341469.0
# 1      Francis Ford Coppola      Marlon Brando      1620367  134966411.0
# 2         Christopher Nolan     Christian Bale      2303232  534858444.0
# 3      Francis Ford Coppola          Al Pacino      1129952   57300000.0
# 4              Sidney Lumet        Henry Fonda       689845    4360000.0
# ..                      ...                ...          ...          ...
# 993  Michelangelo Antonioni     David Hemmings        56513          NaN
# 995           Blake Edwards     Audrey Hepburn       166544          NaN
# 996          George Stevens   Elizabeth Taylor        34075          NaN
# 997          Fred Zinnemann     Burt Lancaster        43374   30500000.0
# 998        Alfred Hitchcock  Tallulah Bankhead        26471          NaN
#
# [724 rows x 11 columns]

# %% [markdown]
# ### **Question 9**
# How can we sort all movies by IMDB rating in descending order? (Movies ko highest se lowest rating ke mutabiq sort karein).

# %%
data.sort_values(by="IMDB_Rating",ascending=False)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 912                Zombieland           2009           A   88 min
# 911        La piel que habito           2011           R  120 min
# 910                 Moneyball           2011       PG-13  133 min
# 909                 Celda 211           2009         NaN  113 min
# 999              The 39 Steps           1935         NaN   86 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 0                         Drama          9.3        80.0
# 1                  Crime, Drama          9.2       100.0
# 2          Action, Crime, Drama          9.0        84.0
# 3                  Crime, Drama          9.0        90.0
# 4                  Crime, Drama          9.0        96.0
# ..                          ...          ...         ...
# 912  Adventure, Comedy, Fantasy          7.6        73.0
# 911     Drama, Horror, Thriller          7.6        70.0
# 910     Biography, Drama, Sport          7.6        87.0
# 909    Action, Adventure, Crime          7.6         NaN
# 999    Crime, Mystery, Thriller          7.6        93.0
#
#                  Director             Star1  No_of_Votes        Gross
# 0          Frank Darabont       Tim Robbins      2343110   28341469.0
# 1    Francis Ford Coppola     Marlon Brando      1620367  134966411.0
# 2       Christopher Nolan    Christian Bale      2303232  534858444.0
# 3    Francis Ford Coppola         Al Pacino      1129952   57300000.0
# 4            Sidney Lumet       Henry Fonda       689845    4360000.0
# ..                    ...               ...          ...          ...
# 912       Ruben Fleischer   Jesse Eisenberg       520041   75590286.0
# 911       Pedro Almodóvar  Antonio Banderas       138959    3185812.0
# 910        Bennett Miller         Brad Pitt       369529   75605492.0
# 909         Daniel Monzón        Luis Tosar        63882          NaN
# 999      Alfred Hitchcock      Robert Donat        51853          NaN
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### **Question 10**
# How can we sort all movies by the number of votes they received? (No_of_Votes ke mutabiq descending order mein sort karein).

# %%
data.sort_values(by="No_of_Votes",ascending=False)
# Out:
#                           Series_Title  Released_Year Certificate  Runtime  \
# 0             The Shawshank Redemption           1994           A  142 min
# 2                      The Dark Knight           2008          UA  152 min
# 8                            Inception           2010          UA  148 min
# 9                           Fight Club           1999           A  139 min
# 6                         Pulp Fiction           1994           A  154 min
# ..                                 ...            ...         ...      ...
# 570                              Raazi           2018          UA  138 min
# 718  Scarface: The Shame of the Nation           1932          PG   93 min
# 694                 La planète sauvage           1973           U   72 min
# 721                  God's Own Country           2017         NaN  104 min
# 264                     Ba wang bie ji           1993           R  171 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 0                        Drama          9.3        80.0     Frank Darabont
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 9                        Drama          8.8        66.0      David Fincher
# 6                 Crime, Drama          8.9        94.0  Quentin Tarantino
# ..                         ...          ...         ...                ...
# 570    Action, Drama, Thriller          7.8         NaN      Meghna Gulzar
# 718       Action, Crime, Drama          7.8        87.0       Howard Hawks
# 694          Animation, Sci-Fi          7.8        73.0        René Laloux
# 721             Drama, Romance          7.7        85.0        Francis Lee
# 264      Drama, Music, Romance          8.1         NaN         Kaige Chen
#
#                  Star1  No_of_Votes        Gross
# 0          Tim Robbins      2343110   28341469.0
# 2       Christian Bale      2303232  534858444.0
# 8    Leonardo DiCaprio      2067042  292576195.0
# 9            Brad Pitt      1854740   37030102.0
# 6        John Travolta      1826188  107928762.0
# ..                 ...          ...          ...
# 570         Alia Bhatt        25344          NaN
# 718     Richard Rosson        25312          NaN
# 694     Barry Bostwick        25229     193817.0
# 721      Josh O'Connor        25198     335609.0
# 264      Leslie Cheung        25088    5216888.0
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### **Question 11**
# Which movie has the longest runtime? (Sabse lambi movie ka naam aur runtime minutes mein nikalye).

# %%
data[data.Runtime==data.Runtime.max()]
# Out:
#                    Series_Title  Released_Year Certificate Runtime  \
# 103              Reservoir Dogs           1992           R  99 min
# 175                 Höstsonaten           1978           U  99 min
# 192          To Be or Not to Be           1942      Passed  99 min
# 209    The Grand Budapest Hotel           2014          UA  99 min
# 260       Trois couleurs: Rouge           1994           U  99 min
# 299      Les quatre cents coups           1959         NaN  99 min
# 311  The Shop Around the Corner           1940         NaN  99 min
# 431     Per un pugno di dollari           1964           A  99 min
# 503           Shaun of the Dead           2004          UA  99 min
# 643                 Waking Life           2001           R  99 min
# 776                     Kung fu           2004          UA  99 min
# 814               Do lok tin si           1995          UA  99 min
# 972                Delicatessen           1991           R  99 min
# 980                Blood Simple           1984           A  99 min
#
#                          Genre  IMDB_Rating  Meta_score              Director  \
# 103     Crime, Drama, Thriller          8.3        79.0     Quentin Tarantino
# 175               Drama, Music          8.2         NaN        Ingmar Bergman
# 192                Comedy, War          8.2        86.0        Ernst Lubitsch
# 209   Adventure, Comedy, Crime          8.1        88.0          Wes Anderson
# 260    Drama, Mystery, Romance          8.1       100.0  Krzysztof Kieslowski
# 299               Crime, Drama          8.1         NaN     François Truffaut
# 311     Comedy, Drama, Romance          8.1        96.0        Ernst Lubitsch
# 431     Action, Drama, Western          8.0        65.0          Sergio Leone
# 503             Comedy, Horror          7.9        76.0          Edgar Wright
# 643  Animation, Drama, Fantasy          7.8        83.0     Richard Linklater
# 776    Action, Comedy, Fantasy          7.7        78.0          Stephen Chow
# 814       Comedy, Crime, Drama          7.7        71.0          Kar-Wai Wong
# 972              Comedy, Crime          7.6        66.0             Marc Caro
# 980     Crime, Drama, Thriller          7.6        82.0             Joel Coen
#
#                   Star1  No_of_Votes       Gross
# 103       Harvey Keitel       918562   2832029.0
# 175      Ingrid Bergman        26875         NaN
# 192      Carole Lombard        29915         NaN
# 209       Ralph Fiennes       707630  59100318.0
# 260         Irène Jacob        90729   4043686.0
# 299   Jean-Pierre Léaud       105291         NaN
# 311   Margaret Sullavan        28450    203300.0
# 431      Clint Eastwood       198219  14500000.0
# 503          Simon Pegg       512249  13542874.0
# 643         Ethan Hawke        60684   2892011.0
# 776        Stephen Chow       127250  17108591.0
# 814            Leon Lai        26429         NaN
# 972  Jean-Pierre Jeunet        80487   1794187.0
# 980          Ethan Coen        87745   2150000.0

# %% [markdown]
# ### **Question 12**
# Which movies have Leonardo DiCaprio listed as the first star (Star1)?

# %%
data[data.Star1=='Leonardo DiCaprio']
# Out:
#                          Series_Title  Released_Year Certificate  Runtime  \
# 8                           Inception           2010          UA  148 min
# 37                       The Departed           2006           A  151 min
# 145                    Shutter Island           2010           A  138 min
# 147           The Wolf of Wall Street           2013           A  180 min
# 243               Catch Me If You Can           2002           A  141 min
# 343                      The Revenant           2015           A  156 min
# 361                     Blood Diamond           2006           A  143 min
# 652                           Titanic           1997          UA  194 min
# 879  Once Upon a Time... in Hollywood           2019           A  161 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 8     Action, Adventure, Sci-Fi          8.8        74.0
# 37       Crime, Drama, Thriller          8.5        85.0
# 145           Mystery, Thriller          8.2        63.0
# 147     Biography, Crime, Drama          8.2        75.0
# 243     Biography, Crime, Drama          8.1        75.0
# 343    Action, Adventure, Drama          8.0        76.0
# 361  Adventure, Drama, Thriller          8.0        64.0
# 652              Drama, Romance          7.8        75.0
# 879               Comedy, Drama          7.6        83.0
#
#                   Director              Star1  No_of_Votes        Gross
# 8        Christopher Nolan  Leonardo DiCaprio      2067042  292576195.0
# 37         Martin Scorsese  Leonardo DiCaprio      1189773  132384315.0
# 145        Martin Scorsese  Leonardo DiCaprio      1129894  128012934.0
# 147        Martin Scorsese  Leonardo DiCaprio      1187498  116900694.0
# 243       Steven Spielberg  Leonardo DiCaprio       832846  164615351.0
# 343  Alejandro G. Iñárritu  Leonardo DiCaprio       705589  183637894.0
# 361           Edward Zwick  Leonardo DiCaprio       499439   57366262.0
# 652          James Cameron  Leonardo DiCaprio      1046089  659325379.0
# 879      Quentin Tarantino  Leonardo DiCaprio       551309  142502728.0

# %% [markdown]
# ### **Question 13**
# What is the average IMDB rating of all movies? (Saari movies ki average rating calculate karein).

# %%
data.IMDB_Rating.mean()
# Out:
# np.float64(7.949299999999999)

# %% [markdown]
# ### **Question 14**
# Dataset ka poora statistical summary (`describe()` function) display karein.

# %%
data.describe()
# Out:
#        Released_Year  IMDB_Rating  Meta_score   No_of_Votes         Gross
# count    1000.000000  1000.000000  843.000000  1.000000e+03  8.310000e+02
# mean     1991.226000     7.949300   77.971530  2.736929e+05  6.803475e+07
# std        23.287018     0.275491   12.376099  3.273727e+05  1.097500e+08
# min      1920.000000     7.600000   28.000000  2.508800e+04  1.305000e+03
# 25%      1976.000000     7.700000   70.000000  5.552625e+04  3.253559e+06
# 50%      1999.000000     7.900000   79.000000  1.385485e+05  2.353089e+07
# 75%      2009.000000     8.100000   87.000000  3.741612e+05  8.075089e+07
# max      2020.000000     9.300000  100.000000  2.343110e+06  9.366622e+08

# %% [markdown]
# ### **Question 15**
# 'Runtime' column se 'min' text ko hata kar use proper integer (numeric) data type mein convert karein.

# %%
data.Runtime.unique()
# Out:
# array(['142 min', '175 min', '152 min', '202 min', '96 min', '201 min',
#        '154 min', '195 min', '148 min', '139 min', '178 min', '161 min',
#        '179 min', '136 min', '146 min', '124 min', '133 min', '160 min',
#        '132 min', '153 min', '169 min', '130 min', '125 min', '189 min',
#        '116 min', '127 min', '118 min', '121 min', '207 min', '122 min',
#        '106 min', '112 min', '151 min', '150 min', '155 min', '119 min',
#        '110 min', '88 min', '137 min', '89 min', '165 min', '109 min',
#        '102 min', '87 min', '126 min', '147 min', '117 min', '181 min',
#        '149 min', '105 min', '164 min', '170 min', '98 min', '101 min',
#        '113 min', '134 min', '229 min', '115 min', '143 min', '95 min',
#        '104 min', '123 min', '131 min', '108 min', '81 min', '99 min',
#        '114 min', '129 min', '228 min', '128 min', '103 min', '107 min',
#        '68 min', '138 min', '156 min', '167 min', '163 min', '186 min',
#        '321 min', '135 min', '140 min', '180 min', '158 min', '210 min',
#        '86 min', '162 min', '177 min', '204 min', '91 min', '172 min',
#        '45 min', '145 min', '100 min', '196 min', '93 min', '120 min',
#        '92 min', '144 min', '80 min', '183 min', '111 min', '141 min',
#        '224 min', '171 min', '188 min', '94 min', '185 min', '85 min',
#        '205 min', '212 min', '238 min', '72 min', '67 min', '76 min',
#        '159 min', '83 min', '90 min', '84 min', '191 min', '197 min',
#        '174 min', '97 min', '75 min', '157 min', '209 min', '82 min',
#        '220 min', '64 min', '184 min', '168 min', '166 min', '192 min',
#        '194 min', '193 min', '69 min', '70 min', '242 min', '79 min',
#        '71 min', '78 min'], dtype=object)

# %%
data.Runtime=data.Runtime.str.replace("min","").astype(int)

# %%
data.Runtime.unique()
# Out:
# array([142, 175, 152, 202,  96, 201, 154, 195, 148, 139, 178, 161, 179,
#        136, 146, 124, 133, 160, 132, 153, 169, 130, 125, 189, 116, 127,
#        118, 121, 207, 122, 106, 112, 151, 150, 155, 119, 110,  88, 137,
#         89, 165, 109, 102,  87, 126, 147, 117, 181, 149, 105, 164, 170,
#         98, 101, 113, 134, 229, 115, 143,  95, 104, 123, 131, 108,  81,
#         99, 114, 129, 228, 128, 103, 107,  68, 138, 156, 167, 163, 186,
#        321, 135, 140, 180, 158, 210,  86, 162, 177, 204,  91, 172,  45,
#        145, 100, 196,  93, 120,  92, 144,  80, 183, 111, 141, 224, 171,
#        188,  94, 185,  85, 205, 212, 238,  72,  67,  76, 159,  83,  90,
#         84, 191, 197, 174,  97,  75, 157, 209,  82, 220,  64, 184, 168,
#        166, 192, 194, 193,  69,  70, 242,  79,  71,  78])

# %% [markdown]
# ### **Question 16**
# 'Gross' column mein jo missing values (NaN) hain, unko pooray column ke median value se fill (impute) karein.

# %%
data.fillna(data.Gross.median(),inplace=True)
data.Gross.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Question 17**
# Har 'Certificate' category mein total kitni movies hain? (Value counts nikalye).

# %%
data.Certificate.value_counts()
# Out:
# Certificate
# U             234
# A             197
# UA            175
# R             146
# 23530892.0    101
# PG-13          43
# PG             37
# Passed         34
# G              12
# Approved       11
# TV-PG           3
# GP              2
# TV-14           1
# 16              1
# TV-MA           1
# Unrated         1
# U/A             1
# Name: count, dtype: int64

# %% [markdown]
# ### **Question 18**
# 'IMDB_Rating' aur 'Meta_score' ke darmiyan correlation coefficient maloom karein.

# %%
correlation = data["IMDB_Rating"].corr(data["Meta_score"])
print(f"The correlation coefficient between IMDB Rating and Meta Score is: {correlation:.4f}")
# Out:
# The correlation coefficient between IMDB Rating and Meta Score is: 0.1483

# %% [markdown]
# ### **Question 19**
# Ek naya column banayein 'Rating_100_Scale' jisme 'IMDB_Rating' ko 10 se multiply kiya gaya ho.

# %%
data["Rating_100_Scale"]=data.IMDB_Rating*10
data
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# 4                12 Angry Men           1957           U       96
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's           1961           A      115
# 996                     Giant           1956           G      201
# 997     From Here to Eternity           1953      Passed      118
# 998                  Lifeboat           1944  23530892.0       97
# 999              The 39 Steps           1935  23530892.0       86
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# 1                Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2        Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3                Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4                Crime, Drama          9.0        96.0          Sidney Lumet
# ..                        ...          ...         ...                   ...
# 995    Comedy, Drama, Romance          7.6        76.0         Blake Edwards
# 996            Drama, Western          7.6        84.0        George Stevens
# 997       Drama, Romance, War          7.6        85.0        Fred Zinnemann
# 998                Drama, War          7.6        78.0      Alfred Hitchcock
# 999  Crime, Mystery, Thriller          7.6        93.0      Alfred Hitchcock
#
#                  Star1  No_of_Votes        Gross  Rating_100_Scale
# 0          Tim Robbins      2343110   28341469.0              93.0
# 1        Marlon Brando      1620367  134966411.0              92.0
# 2       Christian Bale      2303232  534858444.0              90.0
# 3            Al Pacino      1129952   57300000.0              90.0
# 4          Henry Fonda       689845    4360000.0              90.0
# ..                 ...          ...          ...               ...
# 995     Audrey Hepburn       166544   23530892.0              76.0
# 996   Elizabeth Taylor        34075   23530892.0              76.0
# 997     Burt Lancaster        43374   30500000.0              76.0
# 998  Tallulah Bankhead        26471   23530892.0              76.0
# 999       Robert Donat        51853   23530892.0              76.0
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### **Question 20**
# Year 1990 se 2000 (both inclusive) ke darmiyan release hone wali movies ki total count aur list nikaleyin.

# %%
data_1=data[(data.Released_Year>=1990)&(data.Released_Year<=2000)]
data_1.Series_Title.value_counts()
# Out:
# Series_Title
# The Shawshank Redemption        1
# Vampire Hunter D: Bloodlust     1
# Batman: Mask of the Phantasm    1
# Lat sau san taam                1
# Night on Earth                  1
#                                ..
# The Straight Story              1
# Pâfekuto burû                   1
# Festen                          1
# Central do Brasil               1
# The Godfather: Part III         1
# Name: count, Length: 170, dtype: int64

# %% [markdown]
# ### **Question 21**
# (Visualization) IMDB_Rating ka distribution dekhne ke liye ek neat Histogram plot karein.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data.IMDB_Rating)
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Count'>

# %% [markdown]
# ### **Question 22**
# (Visualization) Top 10 Directors aur unki total movies ka ek attractive Bar Chart banayein.

# %%
data_2=data.sort_values(by="IMDB_Rating",ascending=False)
data_2.head(10)
# Out:
#                                          Series_Title  Released_Year  \
# 0                            The Shawshank Redemption           1994
# 1                                       The Godfather           1972
# 2                                     The Dark Knight           2008
# 3                              The Godfather: Part II           1974
# 4                                        12 Angry Men           1957
# 5       The Lord of the Rings: The Return of the King           2003
# 6                                        Pulp Fiction           1994
# 7                                    Schindler's List           1993
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 11                                       Forrest Gump           1994
#
#    Certificate  Runtime                      Genre  IMDB_Rating  Meta_score  \
# 0            A      142                      Drama          9.3        80.0
# 1            A      175               Crime, Drama          9.2       100.0
# 2           UA      152       Action, Crime, Drama          9.0        84.0
# 3            A      202               Crime, Drama          9.0        90.0
# 4            U       96               Crime, Drama          9.0        96.0
# 5            U      201   Action, Adventure, Drama          8.9        94.0
# 6            A      154               Crime, Drama          8.9        94.0
# 7            A      195  Biography, Drama, History          8.9        94.0
# 10           U      178   Action, Adventure, Drama          8.8        92.0
# 11          UA      142             Drama, Romance          8.8        82.0
#
#                 Director           Star1  No_of_Votes        Gross  \
# 0         Frank Darabont     Tim Robbins      2343110   28341469.0
# 1   Francis Ford Coppola   Marlon Brando      1620367  134966411.0
# 2      Christopher Nolan  Christian Bale      2303232  534858444.0
# 3   Francis Ford Coppola       Al Pacino      1129952   57300000.0
# 4           Sidney Lumet     Henry Fonda       689845    4360000.0
# 5          Peter Jackson     Elijah Wood      1642758  377845905.0
# 6      Quentin Tarantino   John Travolta      1826188  107928762.0
# 7       Steven Spielberg     Liam Neeson      1213505   96898818.0
# 10         Peter Jackson     Elijah Wood      1661481  315544750.0
# 11       Robert Zemeckis       Tom Hanks      1809221  330252182.0
#
#     Rating_100_Scale
# 0               93.0
# 1               92.0
# 2               90.0
# 3               90.0
# 4               90.0
# 5               89.0
# 6               89.0
# 7               89.0
# 10              88.0
# 11              88.0

# %% [markdown]
# ### **Question 23**
# (Visualization) IMDB_Rating aur Gross revenue ke darmiyan ek Scatter Plot banayein taake dono ka relation dikhe.

# %%
plot_data=data[["IMDB_Rating","Gross"]].dropna()
sns.scatterplot(data=plot_data)
# Out:
# <Axes: >

# %% [markdown]
# ### **Question 24**
# (Visualization) Genres ka count dekhne ke liye top 5 genres ka ek clean Pie Chart banayein.

# %%
Gen_value_count=data.Genre.value_counts()
top_5_Genre=Gen_value_count.head()
plt.pie(top_5_Genre,labels=top_5_Genre.index,autopct="%i%%",wedgeprops={"edgecolor":"white"})
# Out:
# ([<matplotlib.patches.Wedge at 0x156a31b6710>,
#   <matplotlib.patches.Wedge at 0x156a31b6ad0>,
#   <matplotlib.patches.Wedge at 0x156a31b6e90>,
#   <matplotlib.patches.Wedge at 0x156a31b7250>,
#   <matplotlib.patches.Wedge at 0x156a31b7610>],
#  [Text(0.37291000160331955, 1.0348614065198356, 'Drama'),
#   Text(-1.086208086209152, 0.17364329371977397, 'Drama, Romance'),
#   Text(-0.7016547142792062, -0.8471603519580965, 'Comedy, Drama'),
#   Text(0.28214860762463084, -1.0631990233326414, 'Comedy, Drama, Romance'),
#   Text(0.9987914113982137, -0.4608857955254907, 'Action, Crime, Drama')],
#  [Text(0.20340545541999247, 0.5644698581017284, '38%'),
#   Text(-0.5924771379322646, 0.09471452384714943, '16%'),
#   Text(-0.38272075324320337, -0.4620874647044162, '16%'),
#   Text(0.15389924052252588, -0.5799267399996225, '14%'),
#   Text(0.5447953153081165, -0.2513922521048131, '13%')])

# %% [markdown]
# ### **Question 25**
# (Visualization) Meta_score ka distribution aur outliers check karne ke liye ek Box Plot banayein.

# %%
sns.boxplot(data.Meta_score)
# Out:
# <Axes: ylabel='Meta_score'>

# %% [markdown]
# ### **Question 26**
# (Visualization) Dataset mein 'Certificate' wise average 'Gross' kamai ka ek Bar Plot banayein.

# %%
data.dropna(inplace=True)
avg_data=data.Gross.groupby(data.Certificate).mean()
sns.barplot(avg_data)
# Out:
# <Axes: xlabel='Certificate', ylabel='Gross'>

# %% [markdown]
# ### **Question 27**
# (Visualization) Har saal (Released_Year) kitni movies release hueen, iska ek Line Plot banayein.

# %%
sns.lineplot(data.Released_Year.value_counts())
# Out:
# <Axes: xlabel='Released_Year', ylabel='count'>

# %% [markdown]
# ### **Question 28**
# (Visualization) 'No_of_Votes' ke mutabiq top 5 highest voted movies ka ek Horizontal Bar Chart banayein.

# %%
top_5_highest_voted=data.sort_values(by="No_of_Votes",ascending=False)
top_5_voted=top_5_highest_voted.head()
sns.barplot(
    data=top_5_voted,
    x='No_of_Votes',
    y='Series_Title'
)
# Out:
# <Axes: xlabel='No_of_Votes', ylabel='Series_Title'>

# %% [markdown]
# ### **Question 29**
# Har movie ke 'Genre' column ko split karke check karein ki total unique genres pure dataset mein kitne hain.

# %%
data_unique=data.Genre.str.split(",").explode()
data_unique.nunique()
# Out:
# 32

# %% [markdown]
# ### **Question 30**
# Dataset ko poora clean karne ke baad safely ek nayi csv file 'cleaned_movies.csv' ke naam se save karein.

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  714 non-null    int64
#  2   Certificate    714 non-null    object
#  3   Runtime        714 non-null    object
#  4   Genre          714 non-null    object
#  5   IMDB_Rating    714 non-null    float64
#  6   Meta_score     714 non-null    float64
#  7   Director       714 non-null    object
#  8   Star1          714 non-null    object
#  9   No_of_Votes    714 non-null    int64
#  10  Gross          714 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 83.1+ KB
# None

# %%
data.Runtime=data.Runtime.str.replace("min","").astype(int)

# %%
data.to_csv("cleaned_movies.csv")

# %% [markdown]
# ### **Question 31**
# Kaunsi movies hain jinki 'IMDB_Rating' 8.5 se zyada hai AUR unka 'Gross' revenue 100 million (100,000,000) se zyada hai? (Dual condition filter)

# %%
data[(data.IMDB_Rating>8.5) & (data.Gross>100000000)]
# Out:
#                                          Series_Title  Released_Year  \
# 1                                       The Godfather           1972
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 6                                        Pulp Fiction           1994
# 8                                           Inception           2010
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 11                                       Forrest Gump           1994
# 13              The Lord of the Rings: The Two Towers           2002
# 14                                         The Matrix           1999
# 16     Star Wars: Episode V - The Empire Strikes Back           1980
# 17                    One Flew Over the Cuckoo's Nest           1975
# 21                                       Interstellar           2014
# 24                                Saving Private Ryan           1998
# 25                                     The Green Mile           1999
# 27                                              Se7en           1995
# 28                           The Silence of the Lambs           1991
# 29                                          Star Wars           1977
#
#    Certificate  Runtime                       Genre  IMDB_Rating  Meta_score  \
# 1            A      175                Crime, Drama          9.2       100.0
# 2           UA      152        Action, Crime, Drama          9.0        84.0
# 5            U      201    Action, Adventure, Drama          8.9        94.0
# 6            A      154                Crime, Drama          8.9        94.0
# 8           UA      148   Action, Adventure, Sci-Fi          8.8        74.0
# 10           U      178    Action, Adventure, Drama          8.8        92.0
# 11          UA      142              Drama, Romance          8.8        82.0
# 13          UA      179    Action, Adventure, Drama          8.7        87.0
# 14           A      136              Action, Sci-Fi          8.7        73.0
# 16          UA      124  Action, Adventure, Fantasy          8.7        82.0
# 17           A      133                       Drama          8.7        83.0
# 21          UA      169    Adventure, Drama, Sci-Fi          8.6        74.0
# 24           R      169                  Drama, War          8.6        91.0
# 25           A      189       Crime, Drama, Fantasy          8.6        61.0
# 27           A      127       Crime, Drama, Mystery          8.6        65.0
# 28           A      118      Crime, Drama, Thriller          8.6        85.0
# 29          UA      121  Action, Adventure, Fantasy          8.6        90.0
#
#                 Director                Star1  No_of_Votes        Gross
# 1   Francis Ford Coppola        Marlon Brando      1620367  134966411.0
# 2      Christopher Nolan       Christian Bale      2303232  534858444.0
# 5          Peter Jackson          Elijah Wood      1642758  377845905.0
# 6      Quentin Tarantino        John Travolta      1826188  107928762.0
# 8      Christopher Nolan    Leonardo DiCaprio      2067042  292576195.0
# 10         Peter Jackson          Elijah Wood      1661481  315544750.0
# 11       Robert Zemeckis            Tom Hanks      1809221  330252182.0
# 13         Peter Jackson          Elijah Wood      1485555  342551365.0
# 14        Lana Wachowski      Lilly Wachowski      1676426  171479930.0
# 16        Irvin Kershner          Mark Hamill      1159315  290475067.0
# 17          Milos Forman       Jack Nicholson       918088  112000000.0
# 21     Christopher Nolan  Matthew McConaughey      1512360  188020017.0
# 24      Steven Spielberg            Tom Hanks      1235804  216540909.0
# 25        Frank Darabont            Tom Hanks      1147794  136801374.0
# 27         David Fincher       Morgan Freeman      1445096  100125643.0
# 28        Jonathan Demme         Jodie Foster      1270197  130742922.0
# 29          George Lucas          Mark Hamill      1231473  322740140.0

# %% [markdown]
# ### **Question 32**
# Director 'Christopher Nolan' ki un movies ke naam aur release year nikalein jinka 'Runtime' 140 minutes se zyada hai.

# %%
filtered=data[(data.Director=='Christopher Nolan') & (data.Runtime >140)]
filtered[["Series_Title","Released_Year"]]
# Out:
#              Series_Title  Released_Year
# 2         The Dark Knight           2008
# 8               Inception           2010
# 21           Interstellar           2014
# 63  The Dark Knight Rises           2012

# %% [markdown]
# ### **Question 33**
# Aise actors (Star1) ki list nikalein jinhone 'Action' ya 'Sci-Fi' genre mein kaam kiya hai AUR unki movies ki 'IMDB_Rating' kam az kam 8.0 hai.

# %%
filtered_1=data[data.Genre.str.contains('Action') | data.Genre.str.contains('Sci-Fi')]
filtered_1.Star1[filtered_1.IMDB_Rating>=8.0]
# Out:
# 2             Christian Bale
# 5                Elijah Wood
# 8          Leonardo DiCaprio
# 10               Elijah Wood
# 13               Elijah Wood
#                ...
# 394            Atsuko Tanaka
# 410    Arnold Schwarzenegger
# 426          Charlton Heston
# 431           Clint Eastwood
# 436               John Wayne
# Name: Star1, Length: 68, dtype: object

# %% [markdown]
# ### **Question 34**
# Year 2010 se 2020 ke darmiyan release hone wali un movies ka data filter karein jinko Certificate 'UA' ya 'A' mila hai.

# %%
filter_2=data[(data.Released_Year>=2010) & (data.Released_Year<=2020)]
filter_2[(filter_2.Certificate=="UA") | (filter_2.Certificate=="A")]
# Out:
#                        Series_Title  Released_Year Certificate  Runtime  \
# 8                         Inception           2010          UA      148
# 19                     Gisaengchung           2019           A      132
# 21                     Interstellar           2014          UA      169
# 33                            Joker           2019           A      122
# 34                         Whiplash           2014           A      106
# ..                              ...            ...         ...      ...
# 898  Dawn of the Planet of the Apes           2014          UA      130
# 900                    Serbuan maut           2011           A      101
# 901                    End of Watch           2012           A      109
# 903                  A Star Is Born           2018          UA      136
# 908                        Kick-Ass           2010          UA      117
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 19     Comedy, Drama, Thriller          8.6        96.0       Bong Joon Ho
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 33      Crime, Drama, Thriller          8.5        59.0      Todd Phillips
# 34                Drama, Music          8.5        88.0    Damien Chazelle
# ..                         ...          ...         ...                ...
# 898   Action, Adventure, Drama          7.6        79.0        Matt Reeves
# 900           Action, Thriller          7.6        73.0       Gareth Evans
# 901       Action, Crime, Drama          7.6        68.0         David Ayer
# 903      Drama, Music, Romance          7.6        88.0     Bradley Cooper
# 908      Action, Comedy, Crime          7.6        66.0     Matthew Vaughn
#
#                     Star1  No_of_Votes        Gross
# 8       Leonardo DiCaprio      2067042  292576195.0
# 19           Kang-ho Song       552778   53367844.0
# 21    Matthew McConaughey      1512360  188020017.0
# 33        Joaquin Phoenix       939252  335451311.0
# 34           Miles Teller       717585   13092000.0
# ..                    ...          ...          ...
# 898           Gary Oldman       411599  208545589.0
# 900             Iko Uwais       190531    4105123.0
# 901       Jake Gyllenhaal       228132   41003371.0
# 903             Lady Gaga       334312  215288866.0
# 908  Aaron Taylor-Johnson       524081   48071303.0
#
# [101 rows x 11 columns]

# %% [markdown]
# ### **Question 35**
# Dataset mein 'Meta_score' 90 se zyada aur 'IMDB_Rating' 8.5 se kam wali unique movies kaunsi hain?

# %%
filtered_3=data[(data.Meta_score > 90) & (data.IMDB_Rating < 8.5)]

filtered_3.Series_Title.unique()
# Out:
# array(['WALL·E', 'Apocalypse Now',
#        'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#        'Rear Window', 'Jodaeiye Nader az Simin', 'Toy Story',
#        'Taxi Driver', 'Lawrence of Arabia', 'The Apartment',
#        'North by Northwest', 'Vertigo', "Singin' in the Rain",
#        'Double Indemnity', 'Citizen Kane', 'There Will Be Blood',
#        "Pan's Labyrinth", 'Toy Story 3', 'Ran',
#        'Monty Python and the Holy Grail', 'Some Like It Hot',
#        'All About Eve', 'The Treasure of the Sierra Madre',
#        'Portrait de la jeune fille en feu', 'Inside Out',
#        '12 Years a Slave', 'Spotlight', 'No Country for Old Men',
#        'Trois couleurs: Rouge', 'Platoon', 'Fanny och Alexander',
#        'Chinatown', 'Cool Hand Luke', 'On the Waterfront',
#        'The Third Man', 'Gone with the Wind', 'La La Land',
#        'Le scaphandre et le papillon', 'Ratatouille', 'Secrets & Lies',
#        'Beauty and the Beast', 'Do the Right Thing', 'Annie Hall',
#        'The Last Picture Show', 'Il conformista', 'La dolce vita',
#        'Rio Bravo', 'Touch of Evil', 'A Streetcar Named Desire',
#        'The Best Years of Our Lives', 'The Grapes of Wrath',
#        'The Wizard of Oz', 'All Quiet on the Western Front',
#        'Manbiki kazoku', 'Marriage Story', 'Call Me by Your Name',
#        'Before Midnight', 'Amour', 'The Irishman', 'Boyhood',
#        'My Left Foot: The Story of Christy Brown', 'This Is Spinal Tap',
#        'Le charme discret de la bourgeoisie', 'Patton', 'The Wild Bunch',
#        'Notorious', 'The Adventures of Robin Hood', 'Dunkirk',
#        'Manchester by the Sea', 'Little Women',
#        'Les triplettes de Belleville', 'Wo hu cang long',
#        'The Right Stuff', 'E.T. the Extra-Terrestrial', 'My Fair Lady',
#        'Gravity', 'The Social Network', 'The French Connection',
#        'The African Queen', 'Fantasia', 'The Florida Project', 'Leviafan',
#        "A Hard Day's Night"], dtype=object)

# %% [markdown]
# ### **Question 36**
# (Visualization) 'Drama' aur 'Action' genres ki movies ke 'Gross' revenue ko compare karne ke liye ek Grouped Box Plot ya Violin Plot banayein.

# %%
drama=data[data.Genre.str.contains('Drama')]
action=data[data.Genre.str.contains('Action')]
for_comparision={
    'Gross_revenue_of Drama':drama.Gross,
    'Gross_revenue_of_action':action.Gross
}
sns.boxplot(for_comparision)
# Out:
# <Axes: >

# %% [markdown]
# ### **Question 37**
# Har Director ki un movies ka count maloom karein jinhone 'No_of_Votes' 500,000 (5 lakh) se zyada hasil kiye hain.

# %%
data_1=data.Series_Title[data.No_of_Votes > 500000]
data_1.value_counts()
# Out:
# Series_Title
# The Shawshank Redemption    1
# Her                         1
# The King's Speech           1
# Deadpool                    1
# Slumdog Millionaire         1
#                            ..
# Reservoir Dogs              1
# Full Metal Jacket           1
# Aliens                      1
# Scarface                    1
# Minority Report             1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# ### **Question 38**
# Un movies ke naam aur ratings batayein jinka 'Released_Year' 2000 se pehle ka hai AUR unka 'Gross' unke overall median gross se zyada hai.

# %%
filter_5=data[(data.Released_Year<2000) & (data.Gross>data.Gross.median())]
filter_5[["Series_Title","IMDB_Rating"]]
# Out:
#                            Series_Title  IMDB_Rating
# 1                         The Godfather          9.2
# 3                The Godfather: Part II          9.0
# 6                          Pulp Fiction          8.9
# 7                      Schindler's List          8.9
# 9                            Fight Club          8.8
# ..                                  ...          ...
# 984                    The Muppet Movie          7.6
# 985                Escape from Alcatraz          7.6
# 987                    Midnight Express          7.6
# 988  Close Encounters of the Third Kind          7.6
# 992                     The Jungle Book          7.6
#
# [152 rows x 2 columns]

# %% [markdown]
# ### **Question 39**
# Aisi movies ka data nikalein jahan 'Star1' (Main Actor) aur 'Director' dono bilkul same person hain.

# %%
data[data.Star1==data.Director]
# Out:
#                               Series_Title  Released_Year Certificate  \
# 26                         La vita è bella           1997           U
# 51                            Modern Times           1936           G
# 52                             City Lights           1931           G
# 102                             Braveheart           1995           A
# 124                           Citizen Kane           1941          UA
# 167                             Unforgiven           1992           A
# 225                            Gran Torino           2008           R
# 371  Bom Yeoareum Gaeul Gyeoul Geurigo Bom           2003           R
# 391                            Sling Blade           1996           R
# 402                     Dances with Wolves           1990           U
# 414                             Annie Hall           1977           A
# 530                     This Is Spinal Tap           1984           R
# 533                              Manhattan           1979           R
# 537                     La montaña sagrada           1973           R
# 664                           A Bronx Tale           1993           R
# 691                 The Outlaw Josey Wales           1976           A
# 753                                   Argo           2012           A
# 776                                Kung fu           2004          UA
# 794              Hedwig and the Angry Inch           2001           R
# 799     South Park: Bigger, Longer & Uncut           1999           A
# 845                           Le locataire           1976           R
# 965          The Bridges of Madison County           1995           A
#
#      Runtime                       Genre  IMDB_Rating  Meta_score  \
# 26       116      Comedy, Drama, Romance          8.6        59.0
# 51        87       Comedy, Drama, Family          8.5        96.0
# 52        87      Comedy, Drama, Romance          8.5        99.0
# 102      178   Biography, Drama, History          8.3        68.0
# 124      119              Drama, Mystery          8.3       100.0
# 167      130              Drama, Western          8.2        85.0
# 225      116                       Drama          8.1        72.0
# 371      103              Drama, Romance          8.0        85.0
# 391      135                       Drama          8.0        84.0
# 402      181   Adventure, Drama, Western          8.0        72.0
# 414       93             Comedy, Romance          8.0        92.0
# 530       82               Comedy, Music          7.9        92.0
# 533       96      Comedy, Drama, Romance          7.9        83.0
# 537      114   Adventure, Drama, Fantasy          7.9        76.0
# 664      121       Crime, Drama, Romance          7.8        80.0
# 691      135                     Western          7.8        69.0
# 753      120  Biography, Drama, Thriller          7.7        86.0
# 776       99     Action, Comedy, Fantasy          7.7        78.0
# 794       95        Comedy, Drama, Music          7.7        85.0
# 799       81  Animation, Comedy, Fantasy          7.7        73.0
# 845      126             Drama, Thriller          7.7        71.0
# 965      135              Drama, Romance          7.6        69.0
#
#                   Director                  Star1  No_of_Votes        Gross
# 26         Roberto Benigni        Roberto Benigni       623629   57598247.0
# 51         Charles Chaplin        Charles Chaplin       217881     163245.0
# 52         Charles Chaplin        Charles Chaplin       167839      19181.0
# 102             Mel Gibson             Mel Gibson       959181   75600000.0
# 124           Orson Welles           Orson Welles       403351    1585634.0
# 167         Clint Eastwood         Clint Eastwood       375935  101157447.0
# 225         Clint Eastwood         Clint Eastwood       720450  148095302.0
# 371             Ki-duk Kim             Ki-duk Kim        77520    2380788.0
# 391     Billy Bob Thornton     Billy Bob Thornton        86838   24475416.0
# 402          Kevin Costner          Kevin Costner       240266  184208848.0
# 414            Woody Allen            Woody Allen       251823   39200000.0
# 530             Rob Reiner             Rob Reiner       128812     188751.0
# 533            Woody Allen            Woody Allen       131436   45700000.0
# 537   Alejandro Jodorowsky   Alejandro Jodorowsky        37183      61001.0
# 664         Robert De Niro         Robert De Niro       128171   17266971.0
# 691         Clint Eastwood         Clint Eastwood        65659   31800000.0
# 753            Ben Affleck            Ben Affleck       572581  136025503.0
# 776           Stephen Chow           Stephen Chow       127250   17108591.0
# 794  John Cameron Mitchell  John Cameron Mitchell        31957    3029081.0
# 799            Trey Parker            Trey Parker       192112   52037603.0
# 845         Roman Polanski         Roman Polanski        39889    1924733.0
# 965         Clint Eastwood         Clint Eastwood        73172   71516617.0

# %% [markdown]
# ### **Question 40**
# (Visualization) Top 5 highest rated movies aur unke 'Meta_score' vs 'IMDB_Rating' (scaled to 100) ka ek Side-by-Side Comparison Bar Chart banayein.

# %%
filtered_6=data.sort_values("IMDB_Rating",ascending=False)
top_5=filtered_6.head()
for_plot={
    'Meta_score':top_5.Meta_score,
    'IMDB_Rating':top_5.IMDB_Rating
}
sns.barplot(for_plot)
# Out:
# <Axes: >
